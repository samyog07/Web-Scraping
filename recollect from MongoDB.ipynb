# %%
def bweeks():
    from pymongo import MongoClient
    import dns

    client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
    db = client.Bookshelf
    collection = db['weeks']
    cursor = collection.find({})

    bookweeks = list()

    for document in cursor:
        bookDict = dict()
        bookDict["Rank&Title"] = str(document['Rank']) + '.' + document['Title']
        bookDict["Title"] = document['Title']
        bookDict["Author"] = document['Author']
        #bookDict["Rank"] = document['Rank']
        bookDict["Weeks on List"] = document['Weeks on List']

    bookweeks.append(bookDict)

    return bookDict
    #print(bookDict)

# %%
bweeks()
# Out:
# {'Rank&Title': '15.THE UNHONEYMOONERS',
#  'Title': 'THE UNHONEYMOONERS',
#  'Author': 'Christina Lauren',
#  'Weeks on List': 1}

# %%
def bshares():
    from pymongo import MongoClient
    import dns

    client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
    db = client.Bookshelf
    collection = db['facebook']
    cursor = collection.find({})

    bookshares = list()

    for document in cursor:
        bookDict = dict()
        bookDict["Share Count&Title"] = str(document['Share Count']) + '.' + document['Title']
        #bookDict["Title"] = document['Title']
        #bookDict["Share Count"] = document['Share Count']
        bookDict["Type"] = document['Type']
        bookDict["Abstract"] = document['Abstract']

        bookshares.append(bookDict)
        
    return bookshares

# %%
def bemail():
    from pymongo import MongoClient
    import dns

    client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
    db = client.Bookshelf
    collection = db['email']
    cursor = collection.find({})

    bookemail = list()

    for document in cursor:
        bookDict = dict()
        bookDict["Email Count&Title"] = str(document['Email Count']) + '.' + document['Title']
        #bookDict["Title"] = document['Title']
        #bookDict["Email Count"] = document['Email Count']
        bookDict["Type"] = document['Type']
        bookDict["Abstract"] = document['Abstract']

        bookemail.append(bookDict)

    return bookemail

# %%
def bviews():
    from pymongo import MongoClient
    import dns

    client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
    db = client.Bookshelf
    collection = db['viewed']
    cursor = collection.find({})

    bookviews = list()

    for document in cursor:
        bookDict = dict()
        bookDict["Views&Title"] = str(document['Views']) + '.' + document['Title']
        #bookDict["Title"] = document['Title']
        #bookDict["Views"] = document['Views']
        bookDict["Type"] = document['Type']
        bookDict["Abstract"] = document['Abstract']


        bookviews.append(bookDict)

    return bookviews

# %%
from flask import Flask, render_template

def bviews():
    from pymongo import MongoClient
    import dns

    client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
    db = client.Bookshelf
    collection = db['viewed']
    cursor = collection.find({})

    bookviews = list()

    for document in cursor:
        bookDict = dict()
        bookDict["Views&Title"] = str(document['Views']) + '.' + document['Title']
        #bookDict["Title"] = document['Title']
        #bookDict["Views"] = document['Views']
        bookDict["Type"] = document['Type']
        bookDict["Abstract"] = document['Abstract']


        bookviews.append(bookDict)

    return bookviews

def bemail():
    from pymongo import MongoClient
    import dns

    client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
    db = client.Bookshelf
    collection = db['email']
    cursor = collection.find({})

    bookemail = list()

    for document in cursor:
        bookDict = dict()
        bookDict["Email Count&Title"] = str(document['Email Count']) + '.' + document['Title']
        #bookDict["Title"] = document['Title']
        #bookDict["Email Count"] = document['Email Count']
        bookDict["Type"] = document['Type']
        bookDict["Abstract"] = document['Abstract']

        bookemail.append(bookDict)

    return bookemail

def bshares():
    from pymongo import MongoClient
    import dns

    client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
    db = client.Bookshelf
    collection = db['facebook']
    cursor = collection.find({})

    bookshares = list()

    for document in cursor:
        bookDict = dict()
        bookDict["Share Count&Title"] = str(document['Share Count']) + '.' + document['Title']
        #bookDict["Title"] = document['Title']
        #bookDict["Share Count"] = document['Share Count']
        bookDict["Type"] = document['Type']
        bookDict["Abstract"] = document['Abstract']

        bookshares.append(bookDict)
        
    return bookshares

def bweeks():
    from pymongo import MongoClient
    import dns

    client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
    db = client.Bookshelf
    collection = db['weeks']
    cursor = collection.find({})

    bookweeks = list()

    for document in cursor:
        bookDict = dict()
        bookDict["Rank&Title"] = str(document['Rank']) + '.' + document['Title']
        bookDict["Title"] = document['Title']
        bookDict["Author"] = document['Author']
        bookDict["Rank"] = document['Rank']
        bookDict["Weeks_on_List"] = document['Weeks on List']

        bookweeks.append(bookDict)

    return bookweeks

app = Flask(__name__)

@app.route('/')
def Webpage():
    bookweeks = bweeks()
    bookshares = bshares()
    bookemail = bemail()
    bookviews = bviews()
    return render_template('Webpage.html', weeks=bookweeks, shares=bookshares, email=bookemail, views=bookviews )

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2019-05-29 13:12:10,515] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\jayte\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\jayte\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\jayte\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\jayte\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
# ...
