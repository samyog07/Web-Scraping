# %%
import requests
import time
from pymongo import MongoClient 
client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
db = client.Bookshelf
while True:
    
    r = requests.get("https://api.nytimes.com/svc/books/v3/lists/current/Combined Print and E-Book Fiction.json?api-key=kCHemtJQOPEUfTULs1HAC3iOG1ifDS1K")
    bookList = list()
    if r.status_code == 200:
        data = r.json()
        
        for book in data['results']['books']:
            bookDict = dict()
            bookDict["Title"] = book['title']
            bookDict["Author"] = book['author']
            bookDict["Rank"] = book['rank']
            bookDict["Weeks on List"] = book['weeks_on_list']
            bookDict["Price"] = book['price']

            print(bookDict)
            bookList.append(bookDict)

    else:
        exit()

    db.weeks.delete_many({})
    db.weeks.insert_many(bookList)
    
    time.sleep(24*60*60)
    
    print(bookList)
# Out:
# {'Title': 'WHERE THE CRAWDADS SING', 'Author': 'Delia Owens', 'Rank': 1, 'Weeks on List': 36, 'Price': 0}
# {'Title': 'THE NIGHT WINDOW', 'Author': 'Dean Koontz', 'Rank': 2, 'Weeks on List': 1, 'Price': 0}
# {'Title': 'THE 18TH ABDUCTION', 'Author': 'James Patterson and Maxine Paetro', 'Rank': 3, 'Weeks on List': 3, 'Price': 0}
# {'Title': 'THE MISTER', 'Author': 'E L James', 'Rank': 4, 'Weeks on List': 5, 'Price': 0}
# {'Title': 'PAST TENSE', 'Author': 'Lee Child', 'Rank': 5, 'Weeks on List': 11, 'Price': 0}
# {'Title': 'REDEMPTION', 'Author': 'David Baldacci', 'Rank': 6, 'Weeks on List': 5, 'Price': 0}
# {'Title': 'A GAME OF THRONES', 'Author': 'George RR Martin', 'Rank': 7, 'Weeks on List': 56, 'Price': 0}
# {'Title': 'BLESSING IN DISGUISE', 'Author': 'Danielle Steel', 'Rank': 8, 'Weeks on List': 2, 'Price': 0}
# {'Title': 'NEON PREY', 'Author': 'John Sandford', 'Rank': 9, 'Weeks on List': 4, 'Price': 0}
# ...

# %%
import requests
import time
from pymongo import MongoClient 
client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
db = client.Bookshelf
while True:
    
    r = requests.get("https://api.nytimes.com/svc/mostpopular/v2/shared/1/facebook.json?api-key=kCHemtJQOPEUfTULs1HAC3iOG1ifDS1K") #20
    bookList = list()
    if r.status_code == 200:
        data = r.json()
        
        for book in data['results']:
            bookDict = dict()
            bookDict["Title"] = book['title']
            bookDict["Share Count"] = book['share_count']
            bookDict["Type"] = book['type']
            bookDict["Abstract"] = book['abstract']

            print(bookDict)
            bookList.append(bookDict)

    else:
        exit()

    db.facebook.delete_many({})
    db.facebook.insert_many(bookList)
    
    time.sleep(24*60*60)
    
    print(bookList)

# %%
import requests
import time
from pymongo import MongoClient 
client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
db = client.Bookshelf
while True:
    
    r = requests.get("https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=kCHemtJQOPEUfTULs1HAC3iOG1ifDS1K") #20
    bookList = list()
    if r.status_code == 200:
        data = r.json()
       
        for book in data['results']:
            bookDict = dict()
            bookDict["Title"] = book['title']
            bookDict["Email Count"] = book['email_count']
            bookDict["Type"] = book['type']
            bookDict["Abstract"] = book['abstract']

            print(bookDict)
            bookList.append(bookDict)

    else:
        exit()

    db.email.delete_many({})
    db.email.insert_many(bookList)
    
    time.sleep(24*60*60)
    
    print(bookList)

# %%
import requests
import time
from pymongo import MongoClient 
client = MongoClient('mongodb+srv://jusjai:12321456@bookboards-jbtto.mongodb.net/test?retryWrites=true')
db = client.Bookshelf
while True:
    
    r = requests.get("https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=kCHemtJQOPEUfTULs1HAC3iOG1ifDS1K") #20
    bookList = list()
    if r.status_code == 200:
        data = r.json()
        
        for book in data['results']:
            bookDict = dict()
            bookDict["Title"] = book['title']
            bookDict["Views"] = book['views']
            bookDict["Type"] = book['type']
            bookDict["Abstract"] = book['abstract']

            print(bookDict)
            bookList.append(bookDict)

    else:
        exit()

    db.viewed.delete_many({})
    db.viewed.insert_many(bookList)
    
    time.sleep(24*60*60)
    
    print(bookList)
